# %%
import numpy as np
import matplotlib.pyplot as mlt
from sklearn import datasets
from sklearn.cluster import KMeans

# %%
iris=datasets.load_iris()
X=iris.data[:,:2]
kmeans=KMeans(n_clusters=2,random_state=42)
y_kmeans=kmeans.fit_predict(X)

# %%
mlt.figure(figsize=(10,5))
mlt.scatter(X[:,0],X[:,1],c=y_kmeans,cmap="viridis",s=50)
mlt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='red',marker='X',label="Centeroid")
mlt.xlabel('X')
mlt.ylabel('Y')
mlt.title('K-Means Clustering on Iris Dataset')
mlt.legend()
mlt.show()

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('city_population_vs_profit.csv')
X=df.values
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
kmeans = KMeans(n_clusters=3, random_state=42)
